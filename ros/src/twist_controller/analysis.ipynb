# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
brakes = pd.read_csv('brakes.csv')
throttles = pd.read_csv('throttles.csv')
steers = pd.read_csv('steers.csv')
velocities = pd.read_csv('velocities.csv', delimiter=';', names=['lin', 'cur'])

# %%
plt.plot(steers.proposed)
plt.plot(steers.actual)
plt.legend()

# %%
plt.plot(throttles.proposed)
plt.plot(throttles.actual)
plt.legend()

# %%
plt.plot(brakes.proposed)
plt.plot(brakes.actual)
plt.legend()

# %%
velocities = pd.read_csv('velocities.csv', delimiter=';', names=['lin', 'cur'])

# %%
velocities = pd.read_csv('velocities.csv', delimiter=';', names=['lin', 'cur'])
plt.plot(velocities['lin'])
plt.plot(velocities['cur'])
plt.plot(throttles.proposed)
plt.plot(throttles.actual)
plt.legend()
